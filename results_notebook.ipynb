# %%
from turbine_mamba.utils import calculate_metrics, just_plot, just_plot2

# %% [markdown]
# ### Predictions vs ground truths, residuals and scatters

# %%
just_plot2.main()
# Out:
# Loaded predictions and ground truth from /home/gregory/dtu/deeplearning/DL_Project/turbine_mamba/predictions_ground_truth.npz
# Predictions shape: (1000, 3), Ground Truth shape: (1000, 3)
# Generating plots for Mz1...
# Generating plots for Mz2...
# Generating plots for Mz3...

# %% [markdown]
# ### Simple Predictions vs ground truths

# %%
just_plot.main()
# Out:
# Loaded predictions and ground truth from /home/gregory/dtu/deeplearning/DL_Project/turbine_mamba/predictions_ground_truth.npz
# Predictions shape: (1000, 3), Ground Truth shape: (1000, 3)
# Plotting predictions vs ground truths...
# Plotting for 100 points.
# Comparison plot saved to /home/gregory/dtu/deeplearning/DL_Project/turbine_mamba/reports/run_3/comparison_plot.png
# Loaded predictions and ground truth from /home/gregory/dtu/deeplearning/DL_Project/turbine_mamba/predictions_ground_truth.npz
# Predictions shape: (1000, 3), Ground Truth shape: (1000, 3)
# Plotting residuals...
# Residuals computed with shape: (1000, 3)

# %% [markdown]
# ### Metrics for all three outputs

# %%
calculate_metrics.main()
# Out:
# Loaded predictions and ground truth from /home/gregory/dtu/deeplearning/DL_Project/turbine_mamba/predictions_ground_truth.npz
# Predictions shape: (1000, 3), Ground Truth shape: (1000, 3)
# Calculating metrics for Mz1...
# Metrics for Mz1:
#   MSE: 75.5661
#   MAE: 6.6094
#   R-squared: 0.9530
# Calculating metrics for Mz2...
# Metrics for Mz2:
#   MSE: 104.5593
#   MAE: 7.8498
#   R-squared: 0.9278
# Calculating metrics for Mz3...
# Metrics for Mz3:
#   MSE: 87.3018
#   MAE: 7.2635
#   R-squared: 0.9471
